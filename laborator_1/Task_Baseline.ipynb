# %% [markdown]
# # Data aquisition

# %% [markdown]
# *   Read dataset
#     1.   Unpack
#     2.   Error handler
#
# *   DataLoader
#     1.   Preprocessing
#     2.   Shuffle

# %% [markdown]
# # Graph operations

# %% [markdown]
# # Optimizer

# %% [markdown]
# # Model

# %% [markdown]
# # Train
