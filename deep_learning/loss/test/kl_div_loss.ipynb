# %% [markdown]
# # Import layers

# %%
import time
import numpy as np
import seaborn as sns
import sys
from pathlib import Path

# %%
p = Path()
LOCAL_PATH = str(p.cwd())
ROOT_PATH  = str(p.cwd().parent.parent.parent)
LAYER_PATH = str(p.cwd().parent.parent)
info = """LOCAL_PATH: '{}'
ROOT_PATH : '{}'
LAYER_PATH: '{}'
""".format(LOCAL_PATH, ROOT_PATH, LAYER_PATH)
print(info)

# add:
sys.path.append(LAYER_PATH)
sys.path.append(ROOT_PATH)

from sys_function import *

# %%
sys_remove_modules("loss", "kl_div_loss")

from loss.kl_div_loss import *

# %% [markdown]
# # Build criterion

# %%
criterion = KLDivLoss()

# %%
for _ in range(10000):
    log_p = torch.rand(1, 1, 3, 3)
    q     = torch.rand(1, 1, 3, 3)
    kl = criterion(log_p, q)
    if (kl <= 0):
        print("kl", kl)
        print("log_p", log_p)
        print("q", q)
    else:
        pass
        #print("zb")

# %%
for _ in range(10000):
    log_p = torch.rand(1, 1, 3, 3)
    q     = torch.rand(1, 1, 3, 3)
    
    log_p = F.log_softmax(log_p, dim=0)   # input
    q = F.softmax(q, dim=0)         # target
    kl = F.kl_div(log_p, q)
    if (kl <= 0):
        print("kl", kl)
        print("log_p", log_p)
        print("q", q)
    else:
        print("zb")

# %%
log_p = torch.rand(1, 1, 3, 3)
print("log_p", log_p)

log_p = F.softmax(log_p, dim=-1)   # input
print("log_p", log_p)
