# %% [markdown]
# # Import layers

# %%
import time
import numpy as np
import seaborn as sns
import sys
from pathlib import Path

# %%
p = Path()
LOCAL_PATH = str(p.cwd())
ROOT_PATH  = str(p.cwd().parent.parent.parent)
LAYER_PATH = str(p.cwd().parent.parent)
info = """LOCAL_PATH: '{}'
ROOT_PATH : '{}'
LAYER_PATH: '{}'
""".format(LOCAL_PATH, ROOT_PATH, LAYER_PATH)
print(info)

# add:
sys.path.append(LAYER_PATH)
sys.path.append(ROOT_PATH)

from sys_function import *
# Out:
# LOCAL_PATH: '/home/gheorghe/Desktop/Proiecte/master/CARN/deep_learning/callback/test'
# ROOT_PATH : '/home/gheorghe/Desktop/Proiecte/master/CARN'
# LAYER_PATH: '/home/gheorghe/Desktop/Proiecte/master/CARN/deep_learning'

# %%
sys_remove_modules("callback", "time_acc")

from callback.time_acc import *

# %% [markdown]
# # make class

# %%
callback = TimeAccuracy()

# %%
logs = {"val_acc":0}
for epoch, val_acc in enumerate(np.random.uniform(low=0.5, high=1.0, size=100)):
    callback.on_epoch_begin(epoch)
    time.sleep(2)
    logs["val_acc"] = val_acc
    callback.on_epoch_end(epoch, logs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 4
#       2 for epoch, val_acc in enumerate(np.random.uniform(low=0.5, high=1.0, size=100)):
#       3     callback.on_epoch_begin(epoch)
# ----> 4     time.sleep(2)
#       5     logs["val_acc"] = val_acc
#       6     callback.on_epoch_end(epoch, logs)
#
# KeyboardInterrupt:

# %%
callback.convert(120)
# Out:
# 0.02
